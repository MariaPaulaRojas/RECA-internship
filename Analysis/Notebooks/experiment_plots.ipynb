# %% [markdown]
# # First experiment to create the plots
# Here, we experiment on how to read the data from the EAGLE database and create the first plot to understand which kind of data we have. First, we import the Python packages we are going to use.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.table import Table

# %% [markdown]
# Checking the *directory* in wich the code is running

# %%
os.getcwd()
# Out:
# '/home/paula/Documentos/RECA/RECA-internship/Analysis/Notebooks'

# %% [markdown]
# Reading the query table

# %%
Table.read('../../Data/InitialQuery.csv', format='ascii')
# Out:
# <Table length=15586>
# GalaxyID    DMEllipticity    ... MasaMateriaOscura    MasaGas
#  int64         float64       ...      float64         float64
# -------- ------------------- ... ----------------- -------------
#        1 0.07881416118313611 ...    128357564000.0    83765552.0
#        2 0.14115086845045632 ...    121664340000.0   127600848.0
#        3 0.21260189713746824 ...    110975549000.0   201059248.0
#        4 0.19453083963799633 ...    192370328000.0   346410720.0
#        5 0.22110837478846934 ...    179377750000.0   843632830.0
#        6 0.24307254165203662 ...    138421027000.0  2169467140.0
#        7  0.3355855347361052 ...    219688534000.0  4707850800.0
#        8  0.3622733943958599 ...    308000719000.0  8252066800.0
#        9   0.361990793939168 ...    287110300000.0 10776853500.0
#       10 0.36063488538279587 ...    380288205000.0 16804786200.0
#      ...                 ... ...               ...           ...
#   446942  0.4273122276963356 ...     35357831000.0   877093380.0
#   446943  0.4401495844243357 ...     34536178000.0  1105184900.0
#   447836   0.383052149465297 ...     38958330000.0   275090848.0
#   447837  0.4230303559113422 ...     37524677000.0   243631808.0
#   447838 0.42466042263636217 ...     35797746000.0   260355024.0
#   447839  0.4250478120009574 ...     34651304000.0   324556672.0
#   447840 0.42320823238575955 ...     33438212100.0   348297408.0
#   448916  0.3508882180054994 ...     36007399000.0   775508160.0
#   448917  0.3604796780324365 ...     34038095900.0   729236800.0
#   448918 0.37556205503161055 ...     34095050800.0   779070980.0

# %% [markdown]
# We assign this table as a variable.

# %%
First_table = Table.read('../../Data/InitialQuery.csv', format='ascii')

# %% [markdown]
# Checking the colums of the table

# %%
First_table.columns
# Out:
# <TableColumns names=('GalaxyID','DMEllipticity','DiscToTotal','DispAnisotropy','Ellipticity','KappaCoRot','MedOrbitCircu','RotToDispRatio','Triaxiality','MasaANegro','AcrecionMasaANegro','Masa','MasaMateriaOscura','MasaGas')>

# %% [markdown]
# Making arrays of the columns that will be used

# %%
Morfparam = ['DMEllipticity', 'DiscToTotal', 'DispAnisotropy', 'Ellipticity', 'KappaCoRot', 'MedOrbitCircu', 'RotToDispRatio', 'Triaxiality']
Subhparam = ['MasaANegro', 'AcrecionMasaANegro', 'Masa', 'MasaMateriaOscura', 'MasaGas']
colors = ['gray', 'blue', 'blueviolet', 'tomato', 'peru', 'limegreen', 'crimson', 'seagreen']

# %% [markdown]
# Plotting the data: morphological parameter vs. mass parameters using "for" loops and "enumerate" function.

# %%
fig, ax = plt.subplots(8,5,figsize=(20,20), facecolor= 'white')
fig.tight_layout(pad=4)

for i_mp, mparam in enumerate(Morfparam):
    for i,cparam in enumerate(colors):        
        if i==i_mp:
            for i_sp, sparam in enumerate(Subhparam): 
                ax[i_mp, i_sp].scatter(First_table[mparam], np.log10(First_table[sparam]), color=cparam, alpha=0.2)
                ax[i_mp, i_sp].set_xlabel(mparam)
                ax[i_mp, i_sp].set_ylabel("log("+sparam+")")
# Out:
# <ipython-input-10-0961e0d96035>:8: RuntimeWarning: divide by zero encountered in log10
#   ax[i_mp, i_sp].scatter(First_table[mparam], np.log10(First_table[sparam]), color=cparam, alpha=0.2)

# %% [markdown]
# Saving archives

# %%
fig.savefig('../Figures/FirstData.pdf')

# %%
fig.savefig('../Figures/FirstData.png')
